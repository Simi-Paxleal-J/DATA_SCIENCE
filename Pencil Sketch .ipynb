# %% [markdown]
# # LetsGrowMore

# %% [markdown]
# ## Image to Pencil Sketch with Python

# %% [markdown]
# ### By Snehal Kokare

# %% [markdown]
# In this task, we need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.

# %%
#importing required libraries
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Reading Image

# %%
image = cv2.imread('img8.jpg')
plt.figure(figsize=(12,8))
plt.imshow(image)
plt.axis('off');

# %% [markdown]
# ### Read Image in RGB format and Viewieng it

# %%
im_rgb = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(12,8))
plt.imshow(im_rgb)
plt.title("Original Image")
plt.axis('off');

# %% [markdown]
# ### Converting the Original Image to a Grayscale Image

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray_image
plt.figure(figsize=(12,8))
plt.imshow(gray_image, cmap='gray')
plt.title("GrayScale Image")
plt.axis('off');

# %% [markdown]
# ### Negative Image : Inverted Grayscale Image

# %%
inverted_image = 255 - gray_image                      #(or) inverted_image = cv2.bitwise_not(gray_image)
plt.figure(figsize=(12,8))
plt.imshow(inverted_image, cmap ='gray')
plt.title('Inverted Image')
plt.axis('off');

# %% [markdown]
# ## Blurry Image

# %%
blur = cv2.GaussianBlur(inverted_image,(21,21),0)
plt.figure(figsize=(12,8))
plt.imshow(blur,cmap='gray')
plt.title("Smoothen Image")
plt.axis('off');

# %% [markdown]
# ## Final Pencil Sketch

# %%
sketch = cv2.divide(gray_image, 255 - blur,scale=255)
plt.figure(figsize=(12,8))
plt.imshow(sketch,cmap='gray')
plt.title('Sketch Image')
plt.axis('off');

# %%
plt.figure(figsize=(40,40))

plt.subplot(1,6,1)
plt.imshow(image)
plt.axis("off")
plt.title("Read Image")

plt.subplot(1,6,2)
plt.imshow(im_rgb)
plt.axis("off")
plt.title("Original Image(RGB) ")

plt.subplot(1,6,3)
plt.imshow(gray_image,cmap="gray")
plt.axis("off")
plt.title("Grayscale Image")

plt.subplot(1,6,4)
plt.imshow(inverted_image,cmap="gray")
plt.axis("off")
plt.title("Negative Image")

plt.subplot(1,6,5)
plt.imshow(blur,cmap="gray")
plt.axis("off")
plt.title("Blurred Image")

plt.subplot(1,6,6)
plt.imshow(sketch,cmap="gray")
plt.axis("off")
plt.title("Final Sketch Image")
plt.show()

# %% [markdown]
# We can use this code for different images and have fun viewing the sketches of them.
